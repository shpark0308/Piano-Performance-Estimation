# %% [markdown]
# ### Ⅰ. 라이브러리

# %%
import numpy as np
import pandas as pd

import os
import mido

from mido import MidiFile, MidiTrack, MetaMessage, Message

# %% [markdown]
# ### Ⅱ. 데이터 추출
# - Message
#     - type
#         - note_on : 음표 시작
#         - control_change : 컨트롤러 변경 메시지 ex. 페달 볼륨 조절기 움직임
#         - program_change : 프로그램 변경 메시지 ex. 다양한 소리 또는 패치

# %% [markdown]
# #### 1. pitch (음정) : [  -8192 to 8192 ]
# - 음의 높낮이
# - 주파수 표현

# %% [markdown]
# #### 2. note (음표) : [  0 to 127 ]
# - msg.type = 'note_on' / 'note_off'
#     - 소리의 강도 / 세기 ( velocity )
#     - 지속 시간 ( time, 단위 : tick )

# %% [markdown]
# #### 3. control ( 컨트롤러 번호 ) [ 0 to 127 ]
# - https://www.midi.org/specifications/midi-reference-tables/midi-1-0-control-change-messages-data-bytes-2
# ----
# - control=1  ( Modulation Wheel ( 음향 변화 )) ( 0 : 왼쪽, 63 : 중앙 127 : 오른쪽 )
# - control=7  ( Main Volume 조절 )
# - control=10 ( Pan, 좌우 스테레오 위치 조절 )
# - control=64 ( Damper Pedal on/off (Sustain) ) <= 63 Off 64<= On

# %% [markdown]
# #### 4. program ( 특정 악기 / 사운드 패치 ) [ 0 to 127 ]
# - program_change : 이벤트를 통해, 악기를 변경
# - 피아노, 비트 등의 특정한 사운드 지칭
# ----
# - program=0 : 피아노
# - program=25 : 악기 관련 사운드
# - program=40 : 비트 드럼

# %%
file_name = "piano_pirate.mid"
file_path = os.path.join("midi_data", file_name)

mid = MidiFile(file_path)

# %%
def distribute_msg(mid_track):
    track_dict = {}
    
    track_dict['MetaMessage'] = []
    track_dict['Message'] = []
    track_dict['ETC'] = []
    
    for msg in mid_track:
        
        if isinstance(msg, MetaMessage):
            track_dict['MetaMessage'].append(msg)
            
        elif isinstance(msg, Message):
            track_dict['Message'].append(msg)
            
        else:
            track_dict['ETC'].append(msg)
            
    return track_dict

# %%
def initialize_ticks(mid_track):
    
    df = pd.DataFrame()
    
    time_vec = {}
    time_arr = [0]
    
    for msg in mid_track:
        time = 
        
    time_arr = time_arr[1:]
    
initialize_ticks(track_dict['Message'])
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# #### 4. time // 이것을 어떻게 할 지 좀 더 고민
# - tick : mid.ticks_per_beat
#     - 1박자의 tick 수를 의미
# - tick_interval 을 의미
# - time = 0 ( interval = 0 )
#     - 이전 이벤트와 동시에 발생
#     - 동일한 시간에 기록

# %%
mid.tracks[0]
# Out:
# MidiTrack([
#   MetaMessage('track_name', name="He's A Pirate", time=0),
#   MetaMessage('text', text='By Written by Klaus Badelt', time=0),
#   MetaMessage('copyright', text='Arrangement © 2004 Cerullean Pictures ', time=0),
#   MetaMessage('copyright', text='Original Score © Walt Disney Pictures', time=0),
#   MetaMessage('text', text='Generated by NoteWorthy Composer', time=0),
#   MetaMessage('set_tempo', tempo=300000, time=0),
#   MetaMessage('key_signature', key='F', time=0),
#   MetaMessage('time_signature', numerator=6, denominator=8, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#   MetaMessage('end_of_track', time=0)])

# %%
print(mid.tracks[1][0])
print(mid.tracks[1][1])
print(mid.tracks[1][2])
# Out:
# MetaMessage('midi_port', port=0, time=0)
# MetaMessage('track_name', name='Right Hand', time=0)
# control_change channel=0 control=64 value=0 time=0

# %%
file_name1 = "Prelude1.mid"
file_path1 = os.path.join("midi_data", file_name1)

mid = MidiFile(file_path1)

# %%
mid.tracks[1]
# Out:
# MidiTrack([
#   MetaMessage('midi_port', port=0, time=0),
#   MetaMessage('track_name', name='Right Hand', time=0),
#   Message('control_change', channel=0, control=64, value=0, time=0),
#   Message('program_change', channel=0, program=0, time=0),
#   Message('control_change', channel=0, control=7, value=127, time=0),
#   Message('control_change', channel=0, control=10, value=64, time=0),
#   Message('program_change', channel=0, program=0, time=0),
#   Message('control_change', channel=0, control=7, value=127, time=0),
#   Message('control_change', channel=0, control=10, value=64, time=0),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=57, velocity=110, time=2),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=60, velocity=110, time=2),
#   Message('note_on', channel=0, note=60, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=160),
#   Message('note_on', channel=0, note=57, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=32),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=160),
#   Message('note_on', channel=0, note=57, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=32),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=94),
#   Message('note_on', channel=0, note=57, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=2),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=160),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=32),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=160),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=55, velocity=110, time=2),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=55, velocity=0, time=94),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=128),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=60, velocity=110, time=2),
#   Message('note_on', channel=0, note=60, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=160),
#   Message('note_on', channel=0, note=58, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=32),
#   Message('note_on', channel=0, note=58, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=160),
#   Message('note_on', channel=0, note=58, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=2),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=94),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=160),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=32),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=160),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=32),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=60, velocity=0, time=94),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=2),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=60, velocity=0, time=94),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=60, velocity=0, time=160),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=32),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=60, velocity=0, time=160),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=60, velocity=110, time=2),
#   Message('note_on', channel=0, note=60, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=160),
#   Message('note_on', channel=0, note=57, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=224),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=60, velocity=110, time=2),
#   Message('note_on', channel=0, note=60, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=160),
#   Message('note_on', channel=0, note=57, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=53, velocity=110, time=32),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=53, velocity=0, time=160),
#   Message('note_on', channel=0, note=57, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=2),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=32),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=94),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=2),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=94),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=94),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=128),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=64, velocity=110, time=2),
#   Message('note_on', channel=0, note=64, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=58, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=67, velocity=110, time=0),
#   Message('note_on', channel=0, note=58, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=94),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=0, time=160),
#   Message('note_on', channel=0, note=62, velocity=110, time=128),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=65, velocity=110, time=2),
#   Message('note_on', channel=0, note=65, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=61, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=160),
#   Message('note_on', channel=0, note=61, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=32),
#   Message('note_on', channel=0, note=61, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=160),
#   Message('note_on', channel=0, note=61, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=32),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=94),
#   Message('note_on', channel=0, note=65, velocity=0, time=0),
#   Message('note_on', channel=0, note=59, velocity=110, time=2),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=59, velocity=0, time=94),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=61, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=57, velocity=0, time=94),
#   Message('note_on', channel=0, note=61, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=194),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=96),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=72, velocity=110, time=2),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=160),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=32),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=160),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=32),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=94),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=2),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=94),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=2),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=110, time=2),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=94),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=2),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=128),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=72, velocity=110, time=2),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=160),
#   Message('note_on', channel=0, note=70, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=32),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=160),
#   Message('note_on', channel=0, note=70, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=94),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=2),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=32),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=2),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=32),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=2),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=160),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=224),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=72, velocity=110, time=2),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=160),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=32),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=160),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=2),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=32),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=2),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=82, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=160),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=82, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=32),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=82, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=160),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=82, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=32),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=2),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=2),
#   Message('note_on', channel=0, note=74, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=110, time=128),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=110, time=2),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=2),
#   Message('note_on', channel=0, note=74, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=110, time=128),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=110, time=2),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=73, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=73, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=73, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=73, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=73, velocity=110, time=2),
#   Message('note_on', channel=0, note=73, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=32),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=110, time=2),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=2),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('note_on', channel=0, note=69, velocity=110, time=194),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=2),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=2),
#   Message('note_on', channel=0, note=69, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=482),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=82, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=82, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=290),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=94),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=2),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=94),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=2),
#   Message('note_on', channel=0, note=70, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=482),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=61, velocity=110, time=0),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=61, velocity=0, time=94),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=61, velocity=110, time=2),
#   Message('note_on', channel=0, note=64, velocity=110, time=0),
#   Message('note_on', channel=0, note=61, velocity=0, time=160),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=55, velocity=110, time=32),
#   Message('note_on', channel=0, note=62, velocity=110, time=0),
#   Message('note_on', channel=0, note=55, velocity=0, time=256),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=57, velocity=110, time=0),
#   Message('note_on', channel=0, note=61, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
# ...
#   Message('note_on', channel=0, note=70, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=224),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=110, time=2),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=32),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=160),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=82, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=82, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=32),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=224),
#   Message('note_on', channel=0, note=79, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=110, time=2),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=224),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('note_on', channel=0, note=73, velocity=110, time=2),
#   Message('note_on', channel=0, note=73, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=416),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=82, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=160),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=82, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=416),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=32),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=32),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=32),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=386),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=416),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=416),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=256),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=110, time=2),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=110, time=2),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=256),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=110, time=2),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=110, time=2),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=82, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=256),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=82, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=32),
#   Message('note_on', channel=0, note=74, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=110, time=2),
#   Message('note_on', channel=0, note=76, velocity=0, time=94),
#   Message('note_on', channel=0, note=77, velocity=110, time=2),
#   Message('note_on', channel=0, note=77, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=2),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=32),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=32),
#   Message('note_on', channel=0, note=84, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=160),
#   Message('note_on', channel=0, note=84, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=72, velocity=110, time=0),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=81, velocity=110, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=94),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=81, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=2),
#   Message('note_on', channel=0, note=79, velocity=0, time=94),
#   Message('control_change', channel=0, control=64, value=0, time=386),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=70, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=70, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=416),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=416),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=77, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=77, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=79, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=79, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=32),
#   Message('note_on', channel=0, note=76, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=160),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('control_change', channel=0, control=64, value=0, time=32),
#   Message('control_change', channel=0, control=64, value=127, time=0),
#   Message('note_on', channel=0, note=65, velocity=110, time=0),
#   Message('note_on', channel=0, note=69, velocity=110, time=0),
#   Message('note_on', channel=0, note=74, velocity=110, time=0),
#   Message('note_on', channel=0, note=65, velocity=0, time=256),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=110, time=320),
#   Message('note_on', channel=0, note=62, velocity=0, time=720),
#   MetaMessage('end_of_track', time=0)])

# %%
mid.tracks[1]
# Out:
# MidiTrack([
#   MetaMessage('text', text='RH B', time=0),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=44, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=77, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=52, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=32, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=72, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=65, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=46, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=68, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=47, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=40, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=80, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=50, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=120),
#   Message('note_off', channel=0, note=69, velocity=35, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=70, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=69, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=48, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=69, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=74, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=120),
#   Message('note_off', channel=0, note=69, velocity=66, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=61, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=62, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=63, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=61, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=61, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=16, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=55, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=63, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=44, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=61, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=68, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=47, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=62, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=54, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=40, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=62, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=61, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=38, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=74, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=51, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=30, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=79, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=61, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=52, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=74, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=58, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=41, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=79, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=63, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=120),
#   Message('note_off', channel=0, note=69, velocity=53, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=62, time=60),
#   Message('note_on', channel=0, note=81, velocity=64, time=0),
#   Message('note_off', channel=0, note=81, velocity=59, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=47, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=46, time=60),
#   Message('note_on', channel=0, note=81, velocity=64, time=0),
#   Message('note_off', channel=0, note=81, velocity=54, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=120),
#   Message('note_off', channel=0, note=69, velocity=49, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=53, time=60),
#   Message('note_on', channel=0, note=81, velocity=64, time=0),
#   Message('note_off', channel=0, note=81, velocity=57, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=57, time=60),
#   Message('note_on', channel=0, note=76, velocity=64, time=0),
#   Message('note_off', channel=0, note=76, velocity=61, time=60),
#   Message('note_on', channel=0, note=81, velocity=64, time=0),
#   Message('note_off', channel=0, note=81, velocity=73, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=120),
#   Message('note_off', channel=0, note=66, velocity=20, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=77, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=59, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=52, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=72, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=63, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=120),
#   Message('note_off', channel=0, note=66, velocity=66, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=68, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=47, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=61, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=69, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=76, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=42, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=73, time=60),
#   Message('note_on', channel=0, note=79, velocity=64, time=0),
#   Message('note_off', channel=0, note=79, velocity=51, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=34, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=66, time=60),
#   Message('note_on', channel=0, note=79, velocity=64, time=0),
#   Message('note_off', channel=0, note=79, velocity=58, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=30, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=72, time=60),
#   Message('note_on', channel=0, note=79, velocity=64, time=0),
#   Message('note_off', channel=0, note=79, velocity=61, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=16, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=74, time=60),
#   Message('note_on', channel=0, note=79, velocity=64, time=0),
#   Message('note_off', channel=0, note=79, velocity=72, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=120),
#   Message('note_off', channel=0, note=64, velocity=41, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=59, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=72, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=45, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=61, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=80, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=120),
#   Message('note_off', channel=0, note=64, velocity=46, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=61, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=68, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=43, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=54, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=66, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=120),
#   Message('note_off', channel=0, note=64, velocity=46, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=55, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=69, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=38, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=62, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=70, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=120),
#   Message('note_off', channel=0, note=64, velocity=43, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=57, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=68, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=39, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=58, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=77, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=22, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=72, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=51, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=25, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=82, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=79, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=13, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=76, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=62, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=18, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=69, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=70, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=30, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=51, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=66, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=27, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=51, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=79, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=27, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=52, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=65, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=35, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=52, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=79, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=120),
#   Message('note_off', channel=0, note=64, velocity=31, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=52, time=60),
#   Message('note_on', channel=0, note=73, velocity=64, time=0),
#   Message('note_off', channel=0, note=73, velocity=62, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=24, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=59, time=60),
#   Message('note_on', channel=0, note=73, velocity=64, time=0),
#   Message('note_off', channel=0, note=73, velocity=74, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=120),
#   Message('note_off', channel=0, note=64, velocity=25, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=49, time=60),
#   Message('note_on', channel=0, note=73, velocity=64, time=0),
#   Message('note_off', channel=0, note=73, velocity=61, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=27, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=63, time=60),
#   Message('note_on', channel=0, note=73, velocity=64, time=0),
#   Message('note_off', channel=0, note=73, velocity=63, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=40, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=76, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=58, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=19, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=73, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=73, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=26, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=62, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=49, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=34, time=60),
#   Message('note_on', channel=0, note=69, velocity=64, time=0),
#   Message('note_off', channel=0, note=69, velocity=68, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=74, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=49, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=53, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=59, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=49, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=51, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=72, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=120),
#   Message('note_off', channel=0, note=62, velocity=46, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=54, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=33, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=13, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=62, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=74, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=120),
#   Message('note_off', channel=0, note=60, velocity=40, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=49, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=65, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=32, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=49, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=66, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=120),
#   Message('note_off', channel=0, note=60, velocity=36, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=59, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=69, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=46, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=54, time=60),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=80, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=38, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=68, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=57, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=9, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=69, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=66, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=16, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=62, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=49, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=13, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=69, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=62, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=50, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=66, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=47, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=34, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=62, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=51, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=46, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=68, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=34, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=37, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=55, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=43, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=42, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=66, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=48, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=43, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=66, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=61, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=47, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=58, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=55, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=28, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=57, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=50, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=38, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=53, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=49, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=42, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=69, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=54, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=39, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=62, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=35, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=40, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=63, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=59, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=120),
#   Message('note_off', channel=0, note=58, velocity=45, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=46, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=0, note=58, velocity=46, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=63, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=53, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=120),
#   Message('note_off', channel=0, note=58, velocity=51, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=58, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=33, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=0, note=58, velocity=47, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=61, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=30, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=44, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=46, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=47, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=53, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=43, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=49, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=42, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=27, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=65, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=55, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=36, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=55, time=60),
#   Message('note_on', channel=0, note=63, velocity=64, time=0),
#   Message('note_off', channel=0, note=63, velocity=51, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=38, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=63, velocity=64, time=0),
#   Message('note_off', channel=0, note=63, velocity=65, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=49, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=58, time=60),
#   Message('note_on', channel=0, note=63, velocity=64, time=0),
#   Message('note_off', channel=0, note=63, velocity=52, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=37, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=63, velocity=64, time=0),
#   Message('note_off', channel=0, note=63, velocity=65, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=120),
#   Message('note_off', channel=0, note=59, velocity=50, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=63, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=57, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=42, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=73, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=69, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=120),
#   Message('note_off', channel=0, note=59, velocity=50, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=70, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=58, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=43, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=65, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=65, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=52, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=54, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=51, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=43, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=68, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=65, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=40, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=50, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=51, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=41, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=52, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=58, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=43, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=51, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=48, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=50, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=58, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=36, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=46, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=17, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=55, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=49, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=68, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=49, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=45, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=54, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=65, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=42, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=62, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=57, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=36, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=51, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=44, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=27, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=52, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=48, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=28, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=69, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=47, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=40, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=55, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=58, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=35, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=55, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=59, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=39, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=68, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=39, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=50, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=47, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=74, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=120),
#   Message('note_off', channel=0, note=57, velocity=42, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=57, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=68, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=39, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=66, time=60),
#   Message('note_on', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=0, note=66, velocity=68, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=38, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=57, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=43, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=30, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=53, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=46, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=47, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=59, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=48, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=46, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=62, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=54, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=34, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=65, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=47, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=14, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=44, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=52, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=47, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=61, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=38, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=34, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=68, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=48, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=40, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=53, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=53, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=45, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=69, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=55, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=34, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=55, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=52, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=43, time=60),
#   Message('note_on', channel=0, note=59, velocity=64, time=0),
#   Message('note_off', channel=0, note=59, velocity=58, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=49, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=22, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=0, note=58, velocity=69, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=34, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=45, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=0, note=58, velocity=62, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=49, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=120),
#   Message('note_off', channel=0, note=55, velocity=38, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=0, note=58, velocity=58, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=46, time=60),
#   Message('note_on', channel=0, note=55, velocity=64, time=0),
#   Message('note_off', channel=0, note=55, velocity=34, time=60),
#   Message('note_on', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=0, note=58, velocity=57, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=0, note=64, velocity=52, time=60),
#   Message('note_on', channel=0, note=53, velocity=64, time=120),
#   Message('note_off', channel=0, note=53, velocity=34, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=20, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=63, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=46, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=58, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=46, time=60),
#   Message('note_on', channel=0, note=60, velocity=64, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=64, time=60),
#   Message('note_on', channel=0, note=53, velocity=64, time=0),
#   Message('note_off', channel=0, note=53, velocity=64, time=60),
#   Message('note_on', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=0, note=57, velocity=64, time=60),
#   Message('note_on', channel=0, note=53, velocity=64, time=0),
#   Message('note_off', channel=0, note=53, velocity=64, time=60),
#   Message('note_on', channel=0, note=50, velocity=64, time=0),
#   Message('note_off', channel=0, note=50, velocity=64, time=60),
#   Message('note_on', channel=0, note=53, velocity=64, time=0),
#   Message('note_off', channel=0, note=53, velocity=64, time=60),
#   Message('note_on', channel=0, note=50, velocity=64, time=0),
#   Message('note_off', channel=0, note=50, velocity=64, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=120),
#   Message('note_off', channel=0, note=67, velocity=28, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=62, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=53, time=60),
#   Message('note_on', channel=0, note=77, velocity=64, time=0),
#   Message('note_off', channel=0, note=77, velocity=55, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=61, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=69, time=60),
#   Message('note_on', channel=0, note=74, velocity=64, time=0),
#   Message('note_off', channel=0, note=74, velocity=55, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=74, time=60),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=0, note=67, velocity=52, time=60),
#   Message('note_on', channel=0, note=71, velocity=64, time=0),
#   Message('note_off', channel=0, note=71, velocity=80, time=60),
#   Message('note_on', channel=0, note=62, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=49, time=60),
#   Message('note_on', channel=0, note=65, velocity=64, time=0),
#   Message('note_off', channel=0, note=65, velocity=58, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_on', channel=0, note=65, velocity=64, time=12),
#   Message('note_off', channel=0, note=64, velocity=64, time=3),
#   Message('note_off', channel=0, note=65, velocity=64, time=12),
#   Message('note_on', channel=0, note=64, velocity=64, time=1),
#   Message('note_off', channel=0, note=64, velocity=64, time=30),
#   Message('note_on', channel=0, note=62, velocity=64, time=2),
#   Message('note_off', channel=0, note=62, velocity=68, time=60),
#   Message('note_on', channel=0, note=64, velocity=64, time=0),
#   Message('note_on', channel=0, note=67, velocity=64, time=0),
#   Message('note_on', channel=0, note=72, velocity=64, time=0),
#   Message('note_off', channel=0, note=72, velocity=86, time=960),
#   Message('note_off', channel=0, note=67, velocity=66, time=0),
#   Message('note_off', channel=0, note=64, velocity=65, time=0),
#   MetaMessage('end_of_track', time=0)])

# %%
for idx, track in enumerate(mid.tracks):
    print(f"Track {idx + 1}: {track.name}")
    
    track_dict = distribute_msg(track)
    
    if len(track_dict['Message'])==0:
        continue;
        
    track_msg = track_dict['Message']
    
    df = pd.DataFrame()
    
    #  msg.type == note_on 에 대해서만
    msg_type = []
    
    msg_note = []
    msg_channel = []
    msg_velocity = []
    msg_interval = []
    
    
    msg_pitch = []
    
    msg_control = []
    msg_wheel = []
    msg_pedal = []
    
    msg_time = [0] # 1분 18초 = 78초
    
    msg_off = []
    msg_con = []
    
    for msg in track_msg:
        
        # note off : note_on and velocity == 0
        if msg.type == 'note_on' and msg.velocity == 0:
            msg_typ = 'note_off'
        else:
            msg_typ = msg.type
            
        msg_type.append(msg_typ)
        
                
        if msg_typ == 'note_on':
            
            time = msg.time + msg_time[-1]
            msg_time.append(time)
            
            #print("NOON", time, msg)
        
            msg_note.append(msg.note)
            msg_channel.append(msg.channel)
            msg_velocity.append(msg.velocity)
            msg_interval.append(msg.time) ## 이전 이벤트와의 간격
        
        elif msg_typ == 'note_off':
            time = msg.time + msg_time[-1]
            msg_off.append(time)
            
        elif msg_typ == 'pitchwheel':
            msg_pitch.append(msg.pitch)
        
        elif msg_typ == 'control_change':
            #print(msg.control, msg.value)
            msg_control.append(msg.control)
            time = msg.time + msg_time[-1]
            msg_con.append(time)
            print("C", time, msg)
            
        elif msg_typ == 'program_change':
            print("PRPRPRP", time, msg)
        
            
    msg_time = msg_time[1:]
            
    
    print(np.unique(msg_type))
    print(np.unique(msg_control))
    print(msg_time[-1])
    print(len(msg_time))

    print("============================")
    #print(msg_off)
    #print(msg_con)
    print("============================")
# Out:
# Track 1:
# Track 2:
# ['note_off' 'note_on']
# []
# 7935
# 417
# ============================
# ============================
# Track 3:
# ['note_off' 'note_on']
# []
# 4738
# 134
# ============================
# ============================

# %%
def initialize_note_ticks():
    tick_type = []
    tick_note = []
    tick_chan = []
    tick_velo = []
    
    return tick_type, tick_note, tick_chan, tick_velo

def initialize_ctl_ticks():
    tick_chan = []
    tick_ctl  = []
    tick_val  = []
    
    return tick_chan, tick_ctl, tick_val

def initialize_prog_ticks():
    tick_chan = []
    tick_prog  = []
    
    return tick_chan, tick_prog

# %%
for idx, track in enumerate(mid.tracks):
    print(f"Track {idx + 1}: {track.name}")
    
    track_dict = distribute_msg(track)
    
    if len(track_dict['Message'])==0:
        continue;
        
    track_msg = track_dict['Message']
    
    df_note_col = {'tick', 'count', 'msg_type', 'msg_note', 'msg_velocity', 'msg_channel'}
    df_note = pd.DataFrame(columns = df_note_col)
    
    df_control_col = {'tick', 'count','channel', 'control', 'value'}
    df_ctl = pd.DataFrame(columns = df_control_col)
    
    df_program_col = {'tick', 'count', 'channel', 'program'}
    df_prog = pd.DataFrame(columns = df_program_col)
    
    
    note_idx = 0
    note_cur_time = 0
    note_start = True
    note_tick_type, note_tick_note, note_tick_chan, note_tick_velo = initialize_note_ticks()
    
    ctl_idx = 0
    ctl_cur_time = 0
    ctl_start = True
    ctl_tick_chan, ctl_tick_ctl, ctl_tick_val = initialize_ctl_ticks()
    
    prog_idx = 0
    prog_cur_time = 0
    prog_start = True
    prog_tick_chan, prog_tick_prog = initialize_prog_ticks()
    
    
    for msg in track_msg:
        
        # note off : note_on and velocity == 0
        if msg.type == 'note_on' and msg.velocity == 0:
            msg_typ = 'note_off'
        else:
            msg_typ = msg.type
            
        
        if msg.type == 'note_on' or msg.type == 'note_off':
            if msg.time > 0 :
                
                if note_start == True:
                    note_cur_time = msg.time + note_cur_time
                    note_start = False;
            
                else:
                    note_cur_time = msg.time + note_cur_time
                    note_idx+=1
            
                    df_note.loc[note_idx, "tick"] = note_cur_time
                    df_note.loc[note_idx, "count"] = len(note_tick_note)
                    df_note.loc[note_idx, "msg_type"] = note_tick_type
                    df_note.loc[note_idx, "msg_note"] = note_tick_note
                    df_note.loc[note_idx, "msg_velocity"] = note_tick_velo
                    df_note.loc[note_idx, "msg_channel"] = note_tick_chan
            
                    note_tick_type, note_tick_note, note_tick_chan, note_tick_velo = initialize_note_ticks()
            
            note_tick_type.append(msg_typ)
            note_tick_note.append(msg.note)
            note_tick_chan.append(msg.channel)
            note_tick_velo.append(msg.velocity)
            
        if msg.type == 'control_change':
            
            if msg.time > 0:
                
                if ctl_start == True:
                    ctl_cur_time = msg.time + ctl_cur_time
                    ctl_start = False;
                    
                else:
                    ctl_cur_time = msg.time + ctl_cur_time
                    ctl_idx +=1
                
                    df_ctl.loc[ctl_idx, "tick"] = ctl_cur_time
                    df_ctl.loc[ctl_idx, "count"] = len(ctl_tick_ctl)
                    df_ctl.loc[ctl_idx, "channel"] = ctl_tick_chan
                    df_ctl.loc[ctl_idx, "control"] = ctl_tick_ctl
                    df_ctl.loc[ctl_idx, "value"] = ctl_tick_val
                
                    ctl_tick_chan, ctl_tick_ctl, ctl_tick_val = initialize_ctl_ticks()
        
            ctl_tick_chan.append(msg.channel)
            ctl_tick_ctl.append(msg.control)
            ctl_tick_val.append(msg.value)
            
        if msg.type == 'program_change':
            
            if msg.time > 0:
                if prog_start == True:
                    prog_cur_time = msg.time + prog_cur_time
                    prog_start = False;
                    
                else:
                    prog_cur_time = msg.time + prog_cur_time
                    prog_idx +=1
                
                    df_prog.loc[prog_idx, "tick"] = prog_cur_time
                    df_prog.loc[prog_idx, "count"] = len(prog_tick_prog)
                    df_prog.loc[prog_idx, "channel"] = prog_tick_chan
                    df_prog.loc[prog_idx, "program"] = prog_tick_prog
                
                    prog_tick_chan, prog_tick_prog = initialize_prog_ticks()
        
            prog_tick_chan.append(msg.channel)
            prog_tick_prog.append(msg.program)
         
        #############################################################
        ############ 마지막 과정
        #############################################################
    if len(note_tick_note) > 0:
        note_cur_time = msg.time + note_cur_time
        note_idx+=1
            
        df_note.loc[note_idx, "tick"] = note_cur_time
        df_note.loc[note_idx, "count"] = len(note_tick_note)
        df_note.loc[note_idx, "msg_type"] = note_tick_type
        df_note.loc[note_idx, "msg_note"] = note_tick_note
        df_note.loc[note_idx, "msg_velocity"] = note_tick_velo
        df_note.loc[note_idx, "msg_channel"] = note_tick_chan
            
    if len(ctl_tick_ctl):
        ctl_cur_time = msg.time + ctl_cur_time
        ctl_idx +=1
                
        df_ctl.loc[ctl_idx, "tick"] = ctl_cur_time
        df_ctl.loc[ctl_idx, "count"] = len(ctl_tick_ctl)
        df_ctl.loc[ctl_idx, "channel"] = ctl_tick_chan
        df_ctl.loc[ctl_idx, "control"] = ctl_tick_ctl
        df_ctl.loc[ctl_idx, "value"] = ctl_tick_val
            
    if len(prog_tick_prog):
        prog_cur_time = msg.time + prog_cur_time
        prog_idx +=1
                
        df_prog.loc[prog_idx, "tick"] = prog_cur_time
        df_prog.loc[prog_idx, "count"] = len(prog_tick_prog)
        df_prog.loc[prog_idx, "channel"] = prog_tick_chan
        df_prog.loc[prog_idx, "program"] = prog_tick_prog
            
        
    print(note_cur_time)
    display(df_note)
    print('---------------------')
    display(df_ctl)
    print('---------------------')
    display(df_prog)
    print("==========================")
# Out:
# Track 1: He's A Pirate
# Track 2: Right Hand
# 44174
#       tick           msg_velocity count  \
# 1      192               [110, 0]     2
# 2      286                  [110]     1
# 3      288                    [0]     1
# 4      448                  [110]     1
# 5      480                    [0]     1
# ..     ...                    ...   ...
# 462  42158             [110, 110]     2
# 463  42414  [0, 0, 110, 110, 110]     5
# 464  42734              [0, 0, 0]     3
# 465  43454                  [110]     1
# 466  44174                    [0]     1
#
#                                             msg_type      msg_channel  \
# 1                                [note_on, note_off]           [0, 0]
# 2                                          [note_on]              [0]
# 3                                         [note_off]              [0]
# 4                                          [note_on]              [0]
# 5                                         [note_off]              [0]
# ..                                               ...              ...
# 462                               [note_on, note_on]           [0, 0]
# 463  [note_off, note_off, note_on, note_on, note_on]  [0, 0, 0, 0, 0]
# 464                   [note_off, note_off, note_off]        [0, 0, 0]
# 465                                        [note_on]              [0]
# 466                                       [note_off]              [0]
#
#                  msg_note
# 1                [62, 62]
# 2                    [62]
# 3                    [62]
# 4                    [62]
# 5                    [62]
# ..                    ...
# 462              [69, 76]
# 463  [69, 76, 65, 69, 74]
# 464          [65, 69, 74]
# 465                  [62]
# 466                  [62]
#
# [466 rows x 6 columns]
# ---------------------
#     tick count                         control  \
# 1      4     8  [64, 7, 10, 7, 10, 64, 64, 64]
# 2      6     2                        [64, 64]
# 3      8     2                        [64, 64]
# 4     10     2                        [64, 64]
# 5     12     2                        [64, 64]
# ..   ...   ...                             ...
# 76  5362     2                        [64, 64]
# 77  5778     2                        [64, 64]
# 78  6194     2                        [64, 64]
# 79  6226     2                        [64, 64]
# 80  6946     2                        [64, 64]
#
#                                  value                   channel
# 1   [0, 127, 64, 127, 64, 127, 0, 127]  [0, 0, 0, 0, 0, 0, 0, 0]
# 2                             [0, 127]                    [0, 0]
# 3                             [0, 127]                    [0, 0]
# 4                             [0, 127]                    [0, 0]
# 5                             [0, 127]                    [0, 0]
# ..                                 ...                       ...
# 76                            [0, 127]                    [0, 0]
# 77                            [0, 127]                    [0, 0]
# 78                            [0, 127]                    [0, 0]
# 79                            [0, 127]                    [0, 0]
# 80                            [0, 127]                    [0, 0]
#
# [80 rows x 5 columns]
# ---------------------
#   program tick count channel
# 1  [0, 0]  720     2  [0, 0]
# ==========================
# Track 3: Left Hand
# 47106
#       tick      msg_velocity count                                msg_type  \
# 1      576  [110, 110, 0, 0]     4  [note_on, note_on, note_off, note_off]
# 2      832        [110, 110]     2                      [note_on, note_on]
# 3      864            [0, 0]     2                    [note_off, note_off]
# 4     1120        [110, 110]     2                      [note_on, note_on]
# 5     1280  [0, 0, 110, 110]     4  [note_off, note_off, note_on, note_on]
# ..     ...               ...   ...                                     ...
# 618  46290        [110, 110]     2                      [note_on, note_on]
# 619  46292            [0, 0]     2                    [note_off, note_off]
# 620  46386        [110, 110]     2                      [note_on, note_on]
# 621  47106  [0, 0, 110, 110]     4  [note_off, note_off, note_on, note_on]
# 622  47106            [0, 0]     2                    [note_off, note_off]
#
#       msg_channel          msg_note
# 1    [1, 1, 1, 1]  [26, 38, 26, 38]
# 2          [1, 1]          [26, 38]
# 3          [1, 1]          [26, 38]
# 4          [1, 1]          [26, 38]
# 5    [1, 1, 1, 1]  [26, 38, 38, 50]
# ..            ...               ...
# 618        [1, 1]          [38, 50]
# 619        [1, 1]          [38, 50]
# 620        [1, 1]          [38, 50]
# 621  [1, 1, 1, 1]  [38, 50, 26, 38]
# 622        [1, 1]          [26, 38]
#
# [622 rows x 6 columns]
# ---------------------
#     tick count                 control                       value  \
# 1   2336     6  [7, 10, 7, 10, 64, 64]  [127, 64, 127, 64, 0, 127]
# 2   2338     2                [64, 64]                    [0, 127]
# 3   2340     2                [64, 64]                    [0, 127]
# 4   2342     2                [64, 64]                    [0, 127]
# 5   2344     2                [64, 64]                    [0, 127]
# ..   ...   ...                     ...                         ...
# 72  2568     2                [64, 64]                    [0, 127]
# 73  2570     2                [64, 64]                    [0, 127]
# 74  2572     2                [64, 64]                    [0, 127]
# 75  2574     2                [64, 64]                    [0, 127]
# 76  2574     2                [64, 64]                    [0, 127]
#
#                channel
# 1   [1, 1, 1, 1, 1, 1]
# 2               [1, 1]
# 3               [1, 1]
# 4               [1, 1]
# 5               [1, 1]
# ..                 ...
# 72              [1, 1]
# 73              [1, 1]
# 74              [1, 1]
# 75              [1, 1]
# 76              [1, 1]
#
# [76 rows x 5 columns]
# ---------------------
#   program tick count channel
# 1  [0, 0]    0     2  [1, 1]
# ==========================

# %%
track_dict = {}
track_dict['MetaMessage'] = []
track_dict['MetaMessage'].append(345)

print(track_dict)
# Out:
# {'MetaMessage': [345]}

# %%
for idx, track in enumerate(mid.tracks):
    print(f"Track {i + 1}: {track.name}")
    
    for m
# Out:
# Track 1: He's A Pirate
# Track 2: Right Hand
# Track 3: Left Hand

# %%
mid.tracks[0]
# Out:
# MidiTrack([
#   MetaMessage('track_name', name="He's A Pirate", time=0),
#   MetaMessage('text', text='By Written by Klaus Badelt', time=0),
#   MetaMessage('copyright', text='Arrangement © 2004 Cerullean Pictures ', time=0),
#   MetaMessage('copyright', text='Original Score © Walt Disney Pictures', time=0),
#   MetaMessage('text', text='Generated by NoteWorthy Composer', time=0),
#   MetaMessage('set_tempo', tempo=300000, time=0),
#   MetaMessage('key_signature', key='F', time=0),
#   MetaMessage('time_signature', numerator=6, denominator=8, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#   MetaMessage('end_of_track', time=0)])

# %%
len(mid.tracks[1])
# Out:
# 1285

# %%
file_name2 = "jesu1.mid"
file_path2 = os.path.join("midi_data", file_name2)

mid2 = MidiFile(file_path2)
print(mid2)
# Out:
# MidiFile(type=1, ticks_per_beat=120, tracks=[
#   MidiTrack([
#     MetaMessage('sequencer_specific', data=(0, 0, 65), time=0),
#     MetaMessage('track_name', name='JESU        ', time=0),
#     MetaMessage('key_signature', key='G', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('time_signature', numerator=9, denominator=8, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#     MetaMessage('set_tempo', tempo=500000, time=38340),
#     MetaMessage('end_of_track', time=0)]),
#   MidiTrack([
#     MetaMessage('track_name', name="Jesu, Joy of Man's", time=0),
#     MetaMessage('instrument_name', name='Synths Strings 1', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     Message('control_change', channel=0, control=0, value=80, time=0),
#     Message('control_change', channel=0, control=32, value=0, time=0),
#     Message('program_change', channel=0, program=50, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=60),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=78, velocity=104, time=12),
#     Message('note_on', channel=0, note=78, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=78, velocity=104, time=12),
#     Message('note_on', channel=0, note=78, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=64, velocity=104, time=12),
#     Message('note_on', channel=0, note=64, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=0),
#     Message('note_on', channel=0, note=62, velocity=0, time=336),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=104, time=24),
#     Message('note_on', channel=0, note=67, velocity=104, time=0),
#     Message('note_on', channel=0, note=60, velocity=104, time=0),
#     Message('note_on', channel=0, note=72, velocity=104, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=168),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=60, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=336),
#     Message('note_on', channel=0, note=66, velocity=104, time=24),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=74, velocity=104, time=0),
#     Message('note_on', channel=0, note=62, velocity=104, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=168),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=336),
#     Message('note_on', channel=0, note=67, velocity=104, time=24),
#     Message('note_on', channel=0, note=62, velocity=104, time=0),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=168),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=104, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=64, velocity=104, time=12),
#     Message('note_on', channel=0, note=64, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=104, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=336),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=104, time=24),
#     Message('note_on', channel=0, note=72, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=0),
#     Message('note_on', channel=0, note=60, velocity=104, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=168),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=60, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=104, time=0),
#     Message('note_on', channel=0, note=74, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=336),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=24),
#     Message('note_on', channel=0, note=64, velocity=104, time=0),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=168),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=63, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=116),
#     Message('note_on', channel=0, note=71, velocity=74, time=4),
#     Message('note_on', channel=0, note=72, velocity=68, time=30),
#     Message('note_on', channel=0, note=71, velocity=0, time=14),
#     Message('note_on', channel=0, note=71, velocity=65, time=16),
#     Message('note_on', channel=0, note=66, velocity=67, time=0),
#     Message('note_on', channel=0, note=62, velocity=55, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=14),
#     Message('note_on', channel=0, note=66, velocity=55, time=166),
#     Message('note_on', channel=0, note=60, velocity=46, time=0),
#     Message('note_on', channel=0, note=69, velocity=45, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=8),
#     Message('note_on', channel=0, note=66, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=172),
#     Message('note_on', channel=0, note=66, velocity=0, time=8),
#     Message('note_on', channel=0, note=60, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=40),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=78, velocity=104, time=12),
#     Message('note_on', channel=0, note=78, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=78, velocity=104, time=12),
#     Message('note_on', channel=0, note=78, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=64, velocity=104, time=12),
#     Message('note_on', channel=0, note=64, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=336),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=104, time=24),
#     Message('note_on', channel=0, note=60, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=0),
#     Message('note_on', channel=0, note=72, velocity=104, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=168),
#     Message('note_on', channel=0, note=60, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=336),
#     Message('note_on', channel=0, note=66, velocity=104, time=24),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=74, velocity=104, time=0),
#     Message('note_on', channel=0, note=62, velocity=104, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=168),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=336),
#     Message('note_on', channel=0, note=67, velocity=104, time=24),
#     Message('note_on', channel=0, note=62, velocity=104, time=0),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=168),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=104, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=64, velocity=104, time=12),
#     Message('note_on', channel=0, note=64, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=104, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=104, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=336),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=64, velocity=104, time=24),
#     Message('note_on', channel=0, note=60, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=0),
#     Message('note_on', channel=0, note=72, velocity=104, time=0),
#     Message('note_on', channel=0, note=64, velocity=0, time=168),
#     Message('note_on', channel=0, note=60, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=104, time=0),
#     Message('note_on', channel=0, note=62, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=336),
#     Message('note_on', channel=0, note=74, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=24),
#     Message('note_on', channel=0, note=64, velocity=104, time=0),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=67, velocity=0, time=168),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=116),
#     Message('note_on', channel=0, note=71, velocity=104, time=4),
#     Message('note_on', channel=0, note=72, velocity=104, time=30),
#     Message('note_on', channel=0, note=71, velocity=0, time=14),
#     Message('note_on', channel=0, note=66, velocity=104, time=16),
#     Message('note_on', channel=0, note=71, velocity=104, time=0),
#     Message('note_on', channel=0, note=62, velocity=104, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=14),
#     Message('note_on', channel=0, note=66, velocity=0, time=154),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=60, velocity=104, time=0),
#     Message('note_on', channel=0, note=69, velocity=104, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=168),
#     Message('note_on', channel=0, note=60, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=78, velocity=104, time=12),
#     Message('note_on', channel=0, note=78, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=104, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=78, velocity=104, time=12),
#     Message('note_on', channel=0, note=78, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=64, velocity=104, time=12),
#     Message('note_on', channel=0, note=64, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=104, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=104, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=62, velocity=104, time=12),
#     Message('note_on', channel=0, note=62, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=66, velocity=104, time=12),
#     Message('note_on', channel=0, note=66, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=79, velocity=104, time=12),
#     Message('note_on', channel=0, note=79, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=104, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=104, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=67, velocity=104, time=12),
#     Message('note_on', channel=0, note=67, velocity=0, time=168),
#     Message('note_on', channel=0, note=66, velocity=94, time=13),
#     Message('note_on', channel=0, note=69, velocity=94, time=0),
#     Message('note_on', channel=0, note=66, velocity=0, time=336),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=68, velocity=94, time=24),
#     Message('note_on', channel=0, note=71, velocity=94, time=0),
#     Message('note_on', channel=0, note=62, velocity=94, time=0),
#     Message('note_on', channel=0, note=68, velocity=0, time=168),
#     Message('note_on', channel=0, note=71, velocity=0, time=0),
#     Message('note_on', channel=0, note=62, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=94, time=12),
#     Message('note_on', channel=0, note=64, velocity=94, time=0),
#     Message('note_on', channel=0, note=69, velocity=94, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=336),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=94, time=24),
#     Message('note_on', channel=0, note=64, velocity=94, time=0),
#     Message('note_on', channel=0, note=72, velocity=94, time=0),
#     Message('note_on', channel=0, note=69, velocity=0, time=168),
#     Message('note_on', channel=0, note=64, velocity=0, time=0),
#     Message('note_on', channel=0, note=72, velocity=0, time=0),
#     Message('note_on', channel=0, note=71, velocity=94, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=276),
#     Message('note_on', channel=0, note=72, velocity=94, time=24),
#     Message('note_on', channel=0, note=72, velocity=0, time=24),
#     Message('note_on', channel=0, note=74, velocity=94, time=6),
#     Message('note_on', channel=0, note=74, velocity=0, time=24),
#     Message('note_on', channel=0, note=71, velocity=94, time=6),
#     Message('note_on', channel=0, note=68, velocity=94, time=0),
#     Message('note_on', channel=0, note=71, velocity=0, time=168),
#     Message('note_on', channel=0, note=68, velocity=0, time=0),
#     Message('note_on', channel=0, note=69, velocity=94, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=168),
#     Message('note_on', channel=0, note=69, velocity=94, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=94, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=94, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=94, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=77, velocity=94, time=12),
#     Message('note_on', channel=0, note=77, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=94, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=94, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=81, velocity=94, time=12),
#     Message('note_on', channel=0, note=81, velocity=0, time=48),
#     Message('note_on', channel=0, note=80, velocity=94, time=12),
#     Message('note_on', channel=0, note=80, velocity=0, time=48),
#     Message('note_on', channel=0, note=81, velocity=94, time=12),
#     Message('note_on', channel=0, note=81, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=94, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=94, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=94, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=94, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=94, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=77, velocity=94, time=12),
#     Message('note_on', channel=0, note=77, velocity=0, time=48),
#     Message('note_on', channel=0, note=76, velocity=94, time=12),
#     Message('note_on', channel=0, note=76, velocity=0, time=48),
#     Message('note_on', channel=0, note=74, velocity=94, time=12),
#     Message('note_on', channel=0, note=74, velocity=0, time=48),
#     Message('note_on', channel=0, note=72, velocity=94, time=12),
#     Message('note_on', channel=0, note=72, velocity=0, time=48),
#     Message('note_on', channel=0, note=71, velocity=94, time=12),
#     Message('note_on', channel=0, note=71, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=94, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=64, velocity=94, time=12),
#     Message('note_on', channel=0, note=64, velocity=0, time=48),
#     Message('note_on', channel=0, note=69, velocity=94, time=12),
#     Message('note_on', channel=0, note=69, velocity=0, time=48),
#     Message('note_on', channel=0, note=68, velocity=94, time=12),
# ...
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=96),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=24),
#     Message('note_on', channel=5, note=60, velocity=127, time=6),
#     Message('note_on', channel=5, note=60, velocity=0, time=24),
#     Message('note_on', channel=5, note=59, velocity=127, time=6),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=55, velocity=127, time=12),
#     Message('note_on', channel=5, note=55, velocity=0, time=336),
#     Message('note_on', channel=5, note=57, velocity=127, time=3984),
#     Message('note_on', channel=5, note=57, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=12),
#     Message('note_on', channel=5, note=59, velocity=0, time=276),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=24),
#     Message('note_on', channel=5, note=62, velocity=127, time=6),
#     Message('note_on', channel=5, note=62, velocity=0, time=24),
#     Message('note_on', channel=5, note=59, velocity=127, time=6),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=1272),
#     Message('note_on', channel=5, note=60, velocity=0, time=336),
#     Message('note_on', channel=5, note=62, velocity=127, time=24),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=64, velocity=127, time=12),
#     Message('note_on', channel=5, note=64, velocity=0, time=336),
#     Message('note_on', channel=5, note=64, velocity=127, time=24),
#     Message('note_on', channel=5, note=64, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=276),
#     Message('note_on', channel=5, note=64, velocity=127, time=24),
#     Message('note_on', channel=5, note=64, velocity=0, time=24),
#     Message('note_on', channel=5, note=65, velocity=127, time=6),
#     Message('note_on', channel=5, note=65, velocity=0, time=24),
#     Message('note_on', channel=5, note=62, velocity=127, time=6),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=1272),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=62, velocity=127, time=24),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=12),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=57, velocity=127, time=24),
#     Message('note_on', channel=5, note=57, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=744),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=96),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=24),
#     Message('note_on', channel=5, note=60, velocity=127, time=6),
#     Message('note_on', channel=5, note=60, velocity=0, time=24),
#     Message('note_on', channel=5, note=59, velocity=127, time=6),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=55, velocity=127, time=12),
#     Message('note_on', channel=5, note=55, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=10464),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=62, velocity=127, time=24),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=732),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=96),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=24),
#     Message('note_on', channel=5, note=60, velocity=127, time=6),
#     Message('note_on', channel=5, note=60, velocity=0, time=24),
#     Message('note_on', channel=5, note=59, velocity=127, time=6),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=55, velocity=127, time=12),
#     Message('note_on', channel=5, note=55, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=3444),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=62, velocity=127, time=24),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=732),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=96),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=24),
#     Message('note_on', channel=5, note=60, velocity=127, time=6),
#     Message('note_on', channel=5, note=60, velocity=0, time=24),
#     Message('note_on', channel=5, note=59, velocity=127, time=6),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=55, velocity=127, time=12),
#     Message('note_on', channel=5, note=55, velocity=0, time=336),
#     Message('note_on', channel=5, note=57, velocity=127, time=3984),
#     Message('note_on', channel=5, note=57, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=12),
#     Message('note_on', channel=5, note=59, velocity=0, time=276),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=24),
#     Message('note_on', channel=5, note=62, velocity=127, time=6),
#     Message('note_on', channel=5, note=62, velocity=0, time=24),
#     Message('note_on', channel=5, note=59, velocity=127, time=6),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=1272),
#     Message('note_on', channel=5, note=60, velocity=0, time=336),
#     Message('note_on', channel=5, note=62, velocity=127, time=24),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=64, velocity=127, time=12),
#     Message('note_on', channel=5, note=64, velocity=0, time=336),
#     Message('note_on', channel=5, note=64, velocity=127, time=24),
#     Message('note_on', channel=5, note=64, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=276),
#     Message('note_on', channel=5, note=64, velocity=127, time=24),
#     Message('note_on', channel=5, note=64, velocity=0, time=24),
#     Message('note_on', channel=5, note=65, velocity=127, time=6),
#     Message('note_on', channel=5, note=65, velocity=0, time=24),
#     Message('note_on', channel=5, note=62, velocity=127, time=6),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=1272),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=62, velocity=127, time=24),
#     Message('note_on', channel=5, note=62, velocity=0, time=168),
#     Message('note_on', channel=5, note=60, velocity=127, time=12),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=59, velocity=127, time=12),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=57, velocity=127, time=24),
#     Message('note_on', channel=5, note=57, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=744),
#     Message('note_on', channel=5, note=59, velocity=0, time=336),
#     Message('note_on', channel=5, note=60, velocity=127, time=24),
#     Message('note_on', channel=5, note=60, velocity=0, time=168),
#     Message('note_on', channel=5, note=62, velocity=127, time=12),
#     Message('note_on', channel=5, note=62, velocity=0, time=336),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=96),
#     Message('note_on', channel=5, note=59, velocity=127, time=24),
#     Message('note_on', channel=5, note=59, velocity=0, time=24),
#     Message('note_on', channel=5, note=60, velocity=127, time=6),
#     Message('note_on', channel=5, note=60, velocity=0, time=24),
#     Message('note_on', channel=5, note=59, velocity=127, time=6),
#     Message('note_on', channel=5, note=59, velocity=0, time=168),
#     Message('note_on', channel=5, note=57, velocity=127, time=12),
#     Message('note_on', channel=5, note=57, velocity=0, time=168),
#     Message('note_on', channel=5, note=55, velocity=127, time=12),
#     Message('note_on', channel=5, note=55, velocity=0, time=336),
#     MetaMessage('end_of_track', time=0)]),
#   MidiTrack([
#     MetaMessage('track_name', name='          [74046,757]', time=0),
#     MetaMessage('midi_port', port=0, time=0),
#     MetaMessage('end_of_track', time=0)])
# ])

# %%
len(mid2.tracks)
# Out:
# 8

# %%
mid2.tracks[0]
# Out:
# MidiTrack([
#   MetaMessage('sequencer_specific', data=(0, 0, 65), time=0),
#   MetaMessage('track_name', name='JESU        ', time=0),
#   MetaMessage('key_signature', key='G', time=0),
#   MetaMessage('midi_port', port=0, time=0),
#   MetaMessage('time_signature', numerator=9, denominator=8, clocks_per_click=24, notated_32nd_notes_per_beat=8, time=0),
#   MetaMessage('set_tempo', tempo=500000, time=38340),
#   MetaMessage('end_of_track', time=0)])

# %%
mid2.tracks[1]
# Out:
# MidiTrack([
#   MetaMessage('track_name', name="Jesu, Joy of Man's", time=0),
#   MetaMessage('instrument_name', name='Synths Strings 1', time=0),
#   MetaMessage('midi_port', port=0, time=0),
#   Message('control_change', channel=0, control=0, value=80, time=0),
#   Message('control_change', channel=0, control=32, value=0, time=0),
#   Message('program_change', channel=0, program=50, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=60),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=104, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=104, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=104, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=336),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=104, time=24),
#   Message('note_on', channel=0, note=67, velocity=104, time=0),
#   Message('note_on', channel=0, note=60, velocity=104, time=0),
#   Message('note_on', channel=0, note=72, velocity=104, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=168),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=336),
#   Message('note_on', channel=0, note=66, velocity=104, time=24),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=74, velocity=104, time=0),
#   Message('note_on', channel=0, note=62, velocity=104, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=168),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=336),
#   Message('note_on', channel=0, note=67, velocity=104, time=24),
#   Message('note_on', channel=0, note=62, velocity=104, time=0),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=168),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=104, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=104, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=104, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=336),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=104, time=24),
#   Message('note_on', channel=0, note=72, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=0),
#   Message('note_on', channel=0, note=60, velocity=104, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=168),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=104, time=0),
#   Message('note_on', channel=0, note=74, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=336),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=24),
#   Message('note_on', channel=0, note=64, velocity=104, time=0),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=168),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=63, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=116),
#   Message('note_on', channel=0, note=71, velocity=74, time=4),
#   Message('note_on', channel=0, note=72, velocity=68, time=30),
#   Message('note_on', channel=0, note=71, velocity=0, time=14),
#   Message('note_on', channel=0, note=71, velocity=65, time=16),
#   Message('note_on', channel=0, note=66, velocity=67, time=0),
#   Message('note_on', channel=0, note=62, velocity=55, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=14),
#   Message('note_on', channel=0, note=66, velocity=55, time=166),
#   Message('note_on', channel=0, note=60, velocity=46, time=0),
#   Message('note_on', channel=0, note=69, velocity=45, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=8),
#   Message('note_on', channel=0, note=66, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=172),
#   Message('note_on', channel=0, note=66, velocity=0, time=8),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=40),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=104, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=104, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=104, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=336),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=104, time=24),
#   Message('note_on', channel=0, note=60, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=0),
#   Message('note_on', channel=0, note=72, velocity=104, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=168),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=336),
#   Message('note_on', channel=0, note=66, velocity=104, time=24),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=74, velocity=104, time=0),
#   Message('note_on', channel=0, note=62, velocity=104, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=168),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=336),
#   Message('note_on', channel=0, note=67, velocity=104, time=24),
#   Message('note_on', channel=0, note=62, velocity=104, time=0),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=168),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=104, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=104, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=104, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=104, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=336),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=104, time=24),
#   Message('note_on', channel=0, note=60, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=0),
#   Message('note_on', channel=0, note=72, velocity=104, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=168),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=104, time=0),
#   Message('note_on', channel=0, note=62, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=336),
#   Message('note_on', channel=0, note=74, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=24),
#   Message('note_on', channel=0, note=64, velocity=104, time=0),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=168),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=116),
#   Message('note_on', channel=0, note=71, velocity=104, time=4),
#   Message('note_on', channel=0, note=72, velocity=104, time=30),
#   Message('note_on', channel=0, note=71, velocity=0, time=14),
#   Message('note_on', channel=0, note=66, velocity=104, time=16),
#   Message('note_on', channel=0, note=71, velocity=104, time=0),
#   Message('note_on', channel=0, note=62, velocity=104, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=14),
#   Message('note_on', channel=0, note=66, velocity=0, time=154),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=60, velocity=104, time=0),
#   Message('note_on', channel=0, note=69, velocity=104, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=168),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=104, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=104, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=104, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=104, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=104, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=104, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=104, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=104, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=104, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=104, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=104, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=104, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=168),
#   Message('note_on', channel=0, note=66, velocity=94, time=13),
#   Message('note_on', channel=0, note=69, velocity=94, time=0),
#   Message('note_on', channel=0, note=66, velocity=0, time=336),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=68, velocity=94, time=24),
#   Message('note_on', channel=0, note=71, velocity=94, time=0),
#   Message('note_on', channel=0, note=62, velocity=94, time=0),
#   Message('note_on', channel=0, note=68, velocity=0, time=168),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=64, velocity=94, time=0),
#   Message('note_on', channel=0, note=69, velocity=94, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=336),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=94, time=24),
#   Message('note_on', channel=0, note=64, velocity=94, time=0),
#   Message('note_on', channel=0, note=72, velocity=94, time=0),
#   Message('note_on', channel=0, note=69, velocity=0, time=168),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=276),
#   Message('note_on', channel=0, note=72, velocity=94, time=24),
#   Message('note_on', channel=0, note=72, velocity=0, time=24),
#   Message('note_on', channel=0, note=74, velocity=94, time=6),
#   Message('note_on', channel=0, note=74, velocity=0, time=24),
#   Message('note_on', channel=0, note=71, velocity=94, time=6),
#   Message('note_on', channel=0, note=68, velocity=94, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=168),
#   Message('note_on', channel=0, note=68, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=168),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=77, velocity=94, time=12),
#   Message('note_on', channel=0, note=77, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=81, velocity=94, time=12),
#   Message('note_on', channel=0, note=81, velocity=0, time=48),
#   Message('note_on', channel=0, note=80, velocity=94, time=12),
#   Message('note_on', channel=0, note=80, velocity=0, time=48),
#   Message('note_on', channel=0, note=81, velocity=94, time=12),
#   Message('note_on', channel=0, note=81, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=77, velocity=94, time=12),
#   Message('note_on', channel=0, note=77, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=94, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=68, velocity=94, time=12),
#   Message('note_on', channel=0, note=62, velocity=94, time=0),
#   Message('note_on', channel=0, note=68, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=94, time=0),
#   Message('note_on', channel=0, note=72, velocity=94, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=336),
#   Message('note_on', channel=0, note=69, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=94, time=24),
#   Message('note_on', channel=0, note=62, velocity=94, time=0),
#   Message('note_on', channel=0, note=67, velocity=94, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=168),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=94, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=336),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=94, time=24),
#   Message('note_on', channel=0, note=76, velocity=94, time=0),
#   Message('note_on', channel=0, note=67, velocity=94, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=168),
#   Message('note_on', channel=0, note=76, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=276),
#   Message('note_on', channel=0, note=76, velocity=94, time=24),
#   Message('note_on', channel=0, note=76, velocity=0, time=24),
#   Message('note_on', channel=0, note=77, velocity=94, time=6),
#   Message('note_on', channel=0, note=77, velocity=0, time=24),
# ...
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=94, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=94, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=336),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=72, velocity=94, time=24),
#   Message('note_on', channel=0, note=67, velocity=94, time=0),
#   Message('note_on', channel=0, note=64, velocity=94, time=0),
#   Message('note_on', channel=0, note=60, velocity=94, time=0),
#   Message('note_on', channel=0, note=72, velocity=0, time=168),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=60, velocity=0, time=0),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=62, velocity=94, time=0),
#   Message('note_on', channel=0, note=67, velocity=94, time=0),
#   Message('note_on', channel=0, note=74, velocity=0, time=336),
#   Message('note_on', channel=0, note=62, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=67, velocity=94, time=24),
#   Message('note_on', channel=0, note=64, velocity=94, time=0),
#   Message('note_on', channel=0, note=71, velocity=94, time=0),
#   Message('note_on', channel=0, note=67, velocity=0, time=168),
#   Message('note_on', channel=0, note=64, velocity=0, time=0),
#   Message('note_on', channel=0, note=71, velocity=0, time=0),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=96),
#   Message('note_on', channel=0, note=71, velocity=94, time=24),
#   Message('note_on', channel=0, note=71, velocity=0, time=24),
#   Message('note_on', channel=0, note=72, velocity=94, time=6),
#   Message('note_on', channel=0, note=72, velocity=0, time=24),
#   Message('note_on', channel=0, note=71, velocity=94, time=6),
#   Message('note_on', channel=0, note=71, velocity=0, time=168),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=168),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=94, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=77, velocity=94, time=12),
#   Message('note_on', channel=0, note=77, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=94, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=94, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=94, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=94, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=94, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=94, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=94, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=94, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=94, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=94, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=94, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=76, velocity=94, time=12),
#   Message('note_on', channel=0, note=76, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=94, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=78, velocity=94, time=12),
#   Message('note_on', channel=0, note=78, velocity=0, time=48),
#   Message('note_on', channel=0, note=79, velocity=94, time=12),
#   Message('note_on', channel=0, note=79, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=64, velocity=94, time=12),
#   Message('note_on', channel=0, note=64, velocity=0, time=48),
#   Message('note_on', channel=0, note=74, velocity=94, time=12),
#   Message('note_on', channel=0, note=74, velocity=0, time=48),
#   Message('note_on', channel=0, note=72, velocity=94, time=12),
#   Message('note_on', channel=0, note=72, velocity=0, time=48),
#   Message('note_on', channel=0, note=71, velocity=94, time=12),
#   Message('note_on', channel=0, note=71, velocity=0, time=48),
#   Message('note_on', channel=0, note=69, velocity=94, time=12),
#   Message('note_on', channel=0, note=69, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=94, time=12),
#   Message('note_on', channel=0, note=62, velocity=0, time=48),
#   Message('note_on', channel=0, note=67, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=0, time=48),
#   Message('note_on', channel=0, note=66, velocity=94, time=12),
#   Message('note_on', channel=0, note=66, velocity=0, time=48),
#   Message('note_on', channel=0, note=62, velocity=94, time=12),
#   Message('note_on', channel=0, note=67, velocity=94, time=0),
#   Message('note_on', channel=0, note=59, velocity=94, time=0),
#   Message('note_on', channel=0, note=55, velocity=94, time=0),
#   Message('note_on', channel=0, note=62, velocity=0, time=456),
#   Message('note_on', channel=0, note=67, velocity=0, time=0),
#   Message('note_on', channel=0, note=59, velocity=0, time=0),
#   Message('note_on', channel=0, note=55, velocity=0, time=0),
#   MetaMessage('end_of_track', time=0)])

# %%
// pending
